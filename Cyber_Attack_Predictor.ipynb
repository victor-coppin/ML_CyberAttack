# %% [markdown]
# #  **Projet Machine Learning Cyber Attack**

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
from uaparser import UAParser as parse_ua #import uaparser library to parse device information column
import tensorflow as tf
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %% [markdown]
# ## Import Data

# %% [markdown]
# Import the cybersecurity database from csv to dataframe

# %%
dataset_path = "cybersecurity_attacks.csv"
df = pd.read_csv(dataset_path)

# %% [markdown]
# Import database with the list of Os and Browser End of Care \
# This database will be used to link with os and browser extracted from the user agent column (device information)\
# and add the end of care date for each version of OS and Browser

# %%
df_browser_list = pd.read_excel('list_os_ browsers.xlsx', sheet_name='EOC BW')

# %%
df_OS_list = pd.read_excel('list_os_ browsers.xlsx', sheet_name='EOC OS')

# %% [markdown]
# ## Data Engineering

# %% [markdown]
# ### Extraction of Devices, OS and Browsers

# %% [markdown]
# Function used to parse the device information column and extract OS, Browser and Devices information thanks to \
#     the uaparser package.

# %%
df['parsed_os'] = df['Device Information'].apply(lambda x: parse_ua(x).os)

# %% [markdown]
# Add Parsed_os column to Dataframe df this will provide all informations about the OS as \
# {'name': 'Windows', 'version': '8'}

# %% [markdown]
# Function to concatenate the OS name with the OS version as : Windows 8

# %%
def os_version(row):
    '''
    Will  return a concatenation of os name and version
    '''
    ua = row['Device Information']
    parsed_ua = parse_ua(ua)
    os_name = parsed_ua.os['name']
    os_version = parsed_ua.os['version']
    version = os_version.split(".")[0] # keep just the major version ex: 8.1 -> 8
    return f"{os_name} {version}"

df['version_os'] = df.apply(os_version,axis = 1)

# %% [markdown]
# The following function will return same as above for the browser and the device

# %%
def browser_version(row):
    '''
    Will  return a concatenation of browser name and version
    '''
    ua = row['Device Information']
    parsed_ua = parse_ua(ua)
    browser_name = parsed_ua.browser['name']
    browser_version = parsed_ua.browser['version']
    version = browser_version.split(".")[0]
    return f"{browser_name} {version}"

df['browser_os'] = df.apply(browser_version,axis = 1)

# %%
def device_version(row):
    '''
    Will  return a concatenation of device name and version
    '''
    ua = row['Device Information']
    parsed_ua = parse_ua(ua)
    device_type = parsed_ua.device['type']
    if device_type == None:
        device_type = "computer"
    return device_type

df['device_type'] = df.apply(device_version,axis = 1)

# %% [markdown]
# ### Extraction of the End of Care for OS and Browsers

# %% [markdown]
# Merge df_browser_list and df_OS_list with our df

# %%
df = df.merge(df_OS_list, how='left', left_on="version_os", right_on="Système d'exploitation")

# %%
df = df.merge(df_browser_list, how='left', left_on="browser_os", right_on= "Bibliothèque")

# %% [markdown]
# ## Clean data creating by the above operations

# %% [markdown]
# Delete useless columns

# %%
columns_to_drop = ["parsed_os","Système d'exploitation_x","Version_x","Date de sortie_x","Système d'exploitation_y","Version_y","Date de sortie_y","Bibliothèque","Navigateur"]
df = df.drop(columns_to_drop, axis = 1)

# %% [markdown]
# Year extraction from the df.Timestamp column

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])
df['year_attack'] = df['Timestamp'].dt.year

# %% [markdown]
# Replace NA and Inf values from the merged columns by arbitrary date as 1900\
# NA values appeared by Linux OS lake of information
# inf values have to be replace to avoid errors

# %%
df['Date de fin de support_x'] = df['Date de fin de support_x'].fillna(1900)
df['Date de fin de support_y'] = df['Date de fin de support_y'].fillna(1900)

# %% [markdown]
# Modify the Year values by integers or the end of care os ( support_x) and browser (support_y)
# Then replace the name of columns.

# %%
df['Date de fin de support _OS'] = df['Date de fin de support_x'].astype(int)

# %%
df['Date de fin de support _Browser'] = df['Date de fin de support_y'].astype(int)

# %% [markdown]
# ## Data Engineering II

# %% [markdown]
# Compute the End of Care columns for OS and Browser Columns : \
# The OS and Browser version have been merge with the table df_browser_list df_OS_list to know for each when the version is not updated compared to the attack timestamp\
# We create two new columns which will display if the OS and Browser are end of care : \
# 1 is for still update vs 0 for old version

# %%
df['os_EndOfCare'] = df.apply(lambda row: '1' if row['year_attack'] < row['Date de fin de support _OS'] else '0', axis=1)
df['browser_EndOfCare'] = df.apply(lambda row: '1' if row['year_attack'] < row['Date de fin de support _Browser'] else '0', axis=1)

# %% [markdown]
# Drop useless columns

# %%
columns_to_drop2 = ["Date de fin de support_x", "Date de fin de support_y", "year_attack", "Date de fin de support _OS", "Date de fin de support _Browser"]
df = df.drop(columns_to_drop2, axis = 1)

# %%
df.sample(20)
# Out:
#                 Timestamp Source IP Address Destination IP Address  \
# 30554 2023-06-19 23:55:23   210.142.221.237          161.74.42.215
# 14498 2021-08-12 02:34:06        56.60.1.41        190.138.226.162
# 3659  2021-07-17 06:37:11     204.208.9.108        190.162.252.153
# 36572 2021-07-16 08:43:03      148.37.16.82         56.224.191.183
# 23505 2023-07-07 14:39:34    213.228.78.103         136.204.80.200
# 5216  2021-06-10 22:32:32     111.238.141.3          9.121.249.148
# 33945 2020-06-08 00:59:10    164.32.152.148         93.117.194.116
# 5117  2021-11-29 13:42:11      45.55.148.14          20.21.109.166
# 423   2021-12-10 09:58:17     13.223.196.90           93.57.240.43
# 13130 2020-01-19 04:39:00      82.36.239.64           28.142.68.99
# 24478 2021-09-27 06:31:41      126.12.64.27         170.108.197.88
# 37756 2022-07-14 12:16:09     186.209.9.197          150.71.241.66
# 19036 2022-05-23 05:06:58     207.89.10.225           33.6.252.249
# 21406 2020-01-02 01:47:57   184.236.143.159         118.184.214.51
# 31630 2022-12-24 23:34:03     55.223.32.180         57.174.224.197
# 16082 2022-04-10 06:25:14    33.185.165.237         108.214.213.45
# 33329 2021-01-11 15:38:08     137.52.254.87        149.159.237.135
# 34055 2022-06-18 11:50:59     61.235.217.51          7.120.201.151
# 9219  2020-11-30 09:06:08     87.188.10.144         208.80.151.194
# 33540 2021-01-23 20:59:30   134.200.173.226          99.148.153.63
#
#        Source Port  Destination Port Protocol  Packet Length Packet Type  \
# 30554        35166             40789      TCP           1203        Data
# 14498        57398             29594      UDP           1441     Control
# 3659         28535             40524      TCP           1197        Data
# 36572        42114             64246      UDP            641        Data
# 23505         4669             19457     ICMP             76        Data
# 5216         31393             32875     ICMP            520        Data
# 33945         4526              7309      UDP           1013     Control
# 5117         55033              9150     ICMP            553     Control
# 423           5319             24397      TCP            915     Control
# 13130        56942             19855      UDP            287        Data
# 24478        40157             42699      UDP            441     Control
# 37756        21254             27157      UDP           1180     Control
# 19036        42942             50807      TCP           1332     Control
# 21406        42079             26996      TCP            709        Data
# 31630        37349             16949      TCP           1497        Data
# 16082        42021             34764      TCP           1254     Control
# 33329        56454             36770      TCP           1016        Data
# 34055        32419             30754     ICMP            204     Control
# 9219         49118              3085      TCP            664     Control
# 33540         3708             22270      TCP            880        Data
#
#       Traffic Type                                       Payload Data  ...  \
# 30554         HTTP  Necessitatibus iusto qui dolorem officia ut. A...  ...
# 14498          FTP  Est id fuga beatae voluptatibus explicabo. Per...  ...
# 3659           DNS  Voluptatem numquam repudiandae alias. Reprehen...  ...
# 36572          FTP  Minus illum ut aliquam. Assumenda vitae cum ex...  ...
# 23505         HTTP  Ipsa odio est mollitia delectus aperiam repreh...  ...
# 5216           DNS  Fuga unde unde suscipit nesciunt. Iure repelle...  ...
# 33945          DNS  Aperiam autem repellendus nostrum ipsa. Labori...  ...
# 5117           DNS  Nesciunt quibusdam accusamus quis quo. Quaerat...  ...
# 423           HTTP  Excepturi sint dolor ab. Ab natus excepturi at...  ...
# 13130         HTTP  Temporibus placeat occaecati debitis sit deser...  ...
# 24478          FTP  Facere cupiditate voluptatibus culpa eveniet v...  ...
# 37756          FTP  Deleniti amet vero aperiam. Animi enim neque q...  ...
# 19036         HTTP  Reiciendis voluptates eius optio modi quod. At...  ...
# 21406          FTP  Voluptatibus exercitationem soluta tenetur. Ve...  ...
# 31630          FTP  Laudantium laboriosam repellat alias ex quaera...  ...
# 16082         HTTP  Unde facilis dignissimos. Quasi eaque accusamu...  ...
# 33329          DNS  Non deleniti sequi perspiciatis. Voluptates cu...  ...
# 34055          DNS  Perspiciatis corporis magnam facilis et cupidi...  ...
# 9219           DNS  Minima corrupti modi at vitae excepturi. Unde ...  ...
# 33540          DNS  Magnam vitae amet molestias perspiciatis hic. ...  ...
#
#                       Geo-location Data  Proxy Information Firewall Logs  \
# 30554               Ranchi, Uttarakhand                NaN           NaN
# 14498                Chinsurah, Gujarat                NaN      Log Data
# 3659                Sonipat, Tamil Nadu     122.102.35.239           NaN
# 36572                     Dhule, Punjab       2.155.72.233           NaN
# 23505             Tiruvottiyur, Gujarat      157.204.49.32           NaN
# 5216              Jalandhar, Tamil Nadu                NaN           NaN
# 33945                   Ramgarh, Punjab      213.75.251.65      Log Data
# 5117                    Jaipur, Tripura                NaN      Log Data
# 423                    Howrah, Nagaland                NaN           NaN
# 13130           Ajmer, Himachal Pradesh    141.115.214.110           NaN
# 24478      Sangli-Miraj & Kupwad, Bihar     218.122.104.95           NaN
# 37756             Chapra, Uttar Pradesh         94.167.8.7           NaN
# 19036               Rohtak, Maharashtra      95.146.232.60      Log Data
# 21406           Ramgarh, Andhra Pradesh                NaN      Log Data
# 31630                Kozhikode, Mizoram     177.126.116.57           NaN
# 16082                  Howrah, Nagaland                NaN           NaN
# 33329    Tirunelveli, Arunachal Pradesh                NaN           NaN
# 34055              Khandwa, Maharashtra       83.180.38.27      Log Data
# 9219                     Dewas, Mizoram       14.19.72.105           NaN
# 33540  Tadepalligudem, Himachal Pradesh                NaN           NaN
#
#       IDS/IPS Alerts Log Source     version_os       browser_os device_type  \
# 30554     Alert Data     Server      Mac OS 10        Firefox 3    computer
# 14498            NaN     Server     Windows 95             IE 5    computer
# 3659             NaN   Firewall   Windows NT 4        Firefox 3    computer
# 36572     Alert Data     Server  Windows Vista             IE 5    computer
# 23505     Alert Data     Server      Mac OS 10         Safari 4    computer
# 5216             NaN     Server   Linux x86_64        Firefox 3    computer
# 33945            NaN   Firewall     Windows XP         Safari 5    computer
# 5117             NaN   Firewall     Windows 95             IE 6    computer
# 423              NaN   Firewall      Mac OS 10         Safari 4    computer
# 13130     Alert Data     Server      Mac OS 10         Safari 5    computer
# 24478            NaN     Server      Windows 8         Opera 10    computer
# 37756            NaN     Server  Windows Vista        Chrome 48    computer
# 19036     Alert Data     Server          iOS 4  Mobile Safari 4      mobile
# 21406            NaN   Firewall     Windows 98         Opera 11    computer
# 31630     Alert Data     Server     Linux i686        Chrome 46    computer
# 16082     Alert Data     Server     Windows CE             IE 5    computer
# 33329     Alert Data   Firewall          iOS 3        Chrome 29      tablet
# 34055            NaN   Firewall     Windows 95         Safari 5    computer
# 9219      Alert Data   Firewall   Windows 2000         Safari 5    computer
# 33540     Alert Data     Server   Linux x86_64         Opera 11    computer
#
#       os_EndOfCare browser_EndOfCare
# 30554            0                 0
# 14498            0                 0
# 3659             0                 0
# 36572            0                 0
# 23505            0                 0
# 5216             0                 0
# 33945            0                 0
# 5117             0                 0
# 423              0                 0
# 13130            0                 0
# 24478            1                 0
# 37756            0                 0
# 19036            0                 0
# 21406            0                 0
# 31630            0                 0
# 16082            0                 0
# 33329            0                 0
# 34055            0                 0
# 9219             0                 0
# 33540            0                 0
#
# [20 rows x 30 columns]
